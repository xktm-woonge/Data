# %% [markdown]
# # 13. 원 그래프(기본)

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글 
matplotlib.rcParams['font.size'] = 15 # 폰트 사이즈
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'JavaScript', 'C#', 'C/C++', 'ETC']

plt.pie(values, labels= labels, autopct='%.1f', startangle=90, counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bbed26afd0>,
#   <matplotlib.patches.Wedge at 0x2bbed287790>,
#   <matplotlib.patches.Wedge at 0x2bbed287e50>,
#   <matplotlib.patches.Wedge at 0x2bbed91a790>,
#   <matplotlib.patches.Wedge at 0x2bbed2aac10>,
#   <matplotlib.patches.Wedge at 0x2bbed2d5370>],
#  [Text(0.8899187180267095, 0.6465637441936395, 'Python'),
#   Text(0.4993894763020948, -0.9801072140121813, 'Java'),
#   Text(-0.8899187482945419, -0.6465637025335369, 'JavaScript'),
#   Text(-1.009530053894666, 0.436862759094241, 'C#'),
#   Text(-0.4683571526946127, 0.9953097897236797, 'C/C++'),
#   Text(-0.0690694928507964, 1.0978294062181673, 'ETC')],
#  [Text(0.48541020983275057, 0.3526711331965306, '30.0'),
#   Text(0.27239425980114257, -0.5346039349157352, '25.0'),
#   Text(-0.4854102263424773, -0.3526711104728383, '20.0'),
#   Text(-0.5506527566698177, 0.2382887776877678, '13.0'),
#   Text(-0.2554675378334251, 0.5428962489401888, '10.0'),
#   Text(-0.03767426882770713, 0.5988160397553639, '2.0')])

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'JavaScript', 'C#', 'C/C++', 'ETC']
explode = [0.2,0.1,0,0,0,0]

plt.pie(values, labels=labels, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bbed611970>,
#   <matplotlib.patches.Wedge at 0x2bbed600a90>,
#   <matplotlib.patches.Wedge at 0x2bbed5fe8e0>,
#   <matplotlib.patches.Wedge at 0x2bbed5ead30>,
#   <matplotlib.patches.Wedge at 0x2bbed5ea040>,
#   <matplotlib.patches.Wedge at 0x2bbed5e2880>],
#  [Text(0.764120788592483, 1.051722121304293, 'Python'),
#   Text(-1.0692078698314704, 0.5447885196022856, 'Java'),
#   Text(-0.6465637025335373, -0.8899187482945414, 'JavaScript'),
#   Text(0.4368627590942414, -1.0095300538946659, 'C#'),
#   Text(0.9953097897236797, -0.46835715269461276, 'C/C++'),
#   Text(1.0978294062181673, -0.06906949285079649, 'ETC')])

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend(loc = (1.2,0.3))
plt.show()

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend(loc = (1.2,0.3), title='언어별 선호도')
plt.show()
